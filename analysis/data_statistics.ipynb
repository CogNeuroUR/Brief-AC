# %% [markdown]
# Imports

# %%
from pathlib import Path
from tqdm import tqdm

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
from sklearn.metrics import accuracy_score
import statsmodels.api as sm

# %% [markdown]
# Load data

# %%
path_summary = Path('data/processed/summary_data_cleaned-rt.csv')

df_summary = pd.read_csv(path_summary)

df_summary.head()
# Out:
#    Unnamed: 0  subID  PT Compatibility ProbeType  n_hits  n_falarms  \
# 0           0      1  33    compatible    Action       2          0
# 1           1      1  33    compatible     Scene       5          3
# 2           2      1  33  incompatible    Action       3          1
# 3           3      1  33  incompatible     Scene       2          3
# 4           4      1  50    compatible    Action       4          7
#
#    n_correjections  n_misses    dprime
# 0               18        15  0.727674
# 1               14        13  0.339444
# 2               17        14  0.664319
# 3               13        16 -0.333494
# 4               10        14 -0.541702

# %%
len(np.unique(df_summary.subID))
# Out:
# 20

# %% [markdown]
# # Statistics

# %%
results = sm.stats.AnovaRM(df_summary, depvar='dprime', subject='subID', 
                           within=['PT', 'Compatibility', 'ProbeType']).fit()
print(results)
# Out:
#                          Anova
# ========================================================
#                            F Value Num DF  Den DF Pr > F
# --------------------------------------------------------
# PT                         50.3896 5.0000 95.0000 0.0000
# Compatibility              64.4716 1.0000 19.0000 0.0000
# ProbeType                   1.3215 1.0000 19.0000 0.2646
# PT:Compatibility            6.7050 5.0000 95.0000 0.0000
# PT:ProbeType                6.3270 5.0000 95.0000 0.0000
# Compatibility:ProbeType    40.7003 1.0000 19.0000 0.0000
# PT:Compatibility:ProbeType 11.5508 5.0000 95.0000 0.0000
# ========================================================

# %%
results_actions = sm.stats.AnovaRM(df_summary[df_summary.ProbeType == 'Action'],
                                   depvar='dprime', subject='subID', 
                                   within=['PT', 'Compatibility']).fit()
print(results_actions)
# Out:
#                     Anova
# ==============================================
#                  F Value Num DF  Den DF Pr > F
# ----------------------------------------------
# PT               41.3823 5.0000 95.0000 0.0000
# Compatibility     1.1538 1.0000 19.0000 0.2962
# PT:Compatibility  1.3440 5.0000 95.0000 0.2526
# ==============================================

# %%
results_scenes = sm.stats.AnovaRM(df_summary[df_summary.ProbeType == 'Scene'],
                                   depvar='dprime', subject='subID', 
                                   within=['PT', 'Compatibility']).fit()
print(results_scenes)
# Out:
#                     Anova
# ==============================================
#                  F Value Num DF  Den DF Pr > F
# ----------------------------------------------
# PT               22.9872 5.0000 95.0000 0.0000
# Compatibility    62.4503 1.0000 19.0000 0.0000
# PT:Compatibility 14.5528 5.0000 95.0000 0.0000
# ==============================================

# %% [markdown]
# **How much is scene recognition affected by incompatible actions at short vs long PTs?**

# %%
# Add rangePT column to df_summary

l_range = []

for index, row in df_summary.iterrows():
    if row["PT"] < 80:
        l_range.append('short')
    else:
        l_range.append('long')

# Add column to df_summary
d
# Out:
# -0.6073989891762164

# %%
df_summary[(df_summary.PT < 80) &
           (df_summary.ProbeType == 'Scene') & 
           (df_summary.Compatibility == 'incompatible')]
# Out:
#      subID  PT Compatibility ProbeType  n_hits  n_falarms  n_correjections  \
# 3        1  33  incompatible     Scene       2          3               13
# 7        1  50  incompatible     Scene       7          5               12
# 11       1  67  incompatible     Scene       8          6               11
# 27       2  33  incompatible     Scene       1          1               16
# 31       2  50  incompatible     Scene       4          5               12
# 35       2  67  incompatible     Scene       5          3               14
# 51       3  33  incompatible     Scene       9          6               11
# 55       3  50  incompatible     Scene       7          5               13
# 59       3  67  incompatible     Scene       9          8                9
# 75       4  33  incompatible     Scene      10          4               12
# 79       4  50  incompatible     Scene      12          4               13
# 83       4  67  incompatible     Scene      14          3               15
# 99       5  33  incompatible     Scene       7         11                7
# 103      5  50  incompatible     Scene      10          6               12
# 107      5  67  incompatible     Scene       7          8                9
# 123      6  33  incompatible     Scene       1          1               16
# 127      6  50  incompatible     Scene       2          1               16
# 131      6  67  incompatible     Scene       2          1               16
# 147      7  33  incompatible     Scene      11          8               10
# 151      7  50  incompatible     Scene      13          9                9
# 155      7  67  incompatible     Scene      11          8               10
# 171      8  33  incompatible     Scene       5          0               18
# 175      8  50  incompatible     Scene       5          2               15
# 179      8  67  incompatible     Scene       6          3               15
# 195      9  33  incompatible     Scene       4          7               10
# 199      9  50  incompatible     Scene       3          0               18
# 203      9  67  incompatible     Scene       0          1               17
# 219     10  33  incompatible     Scene       8         10                7
# 223     10  50  incompatible     Scene       6          5               13
# 227     10  67  incompatible     Scene       5          5               12
# 243     11  33  incompatible     Scene      11         10                7
# 247     11  50  incompatible     Scene       9          6               12
# 251     11  67  incompatible     Scene       7          9                9
# 267     12  33  incompatible     Scene       8          6               12
# 271     12  50  incompatible     Scene      14          9                8
# 275     12  67  incompatible     Scene      12          9                8
# 291     13  33  incompatible     Scene       6          6               11
# 295     13  50  incompatible     Scene       7          5               12
# 299     13  67  incompatible     Scene       7          3               14
# 315     14  33  incompatible     Scene      13          6               12
# 319     14  50  incompatible     Scene       6          4               14
# 323     14  67  incompatible     Scene      10          6               12
# 339     15  33  incompatible     Scene      10          9                8
# 343     15  50  incompatible     Scene      12          6               12
# 347     15  67  incompatible     Scene       3          7               10
# 363     16  33  incompatible     Scene       3          1               16
# 367     16  50  incompatible     Scene       2          3               14
# 371     16  67  incompatible     Scene       1          1               17
#
#      n_misses    dprime
# 3          16 -0.333494
# 7          11  0.259179
# 11         10  0.237682
# 27         17 -0.028492
# 31         14 -0.223315
# 35         12  0.387504
# 51          9  0.377392
# 55         11  0.307240
# 59          9  0.073791
# 75          8  0.814200
# 79          6  1.152250
# 83          3  1.896321
# 99         10 -0.505224
# 103         7  0.653735
# 107         9 -0.083519
# 123        16  0.000000
# 127        16  0.344086
# 131        16  0.344086
# 147         5  0.628487
# 151         4  0.721522
# 155         5  0.628487
# 171        12  1.373111
# 175        13  0.597376
# 179        11  0.590030
# 195        14 -0.541702
# 199        15  0.947084
# 203        17 -0.296291
# 219        10 -0.362718
# 223        11  0.212064
# 227        12  0.000000
# 243         7  0.059208
# 247         8  0.504519
# 251        10 -0.223008
# 267         9  0.356936
# 271         4  0.690918
# 275         6  0.356936
# 291         9  0.124045
# 295        10  0.318387
# 299        11  0.646683
# 315         4  1.152250
# 319        11  0.387318
# 323         7  0.653735
# 339         8  0.065919
# 343         6  0.861455
# 347        15 -0.744414
# 363        14  0.635827
# 367        16 -0.291741
# 371        17  0.000000

# %% [markdown]
# ## Reaction Time

# %%
path_data = Path('data/processed/trials_BriefAC-v2_rt-cleaned.csv')

df_trials = pd.read_csv(path_data)

df_trials.head()
# Out:
#    Unnamed: 0  subID  keyYes  trialNr  picID   Context         Action  \
# 0           0      1      39        3    389  workshop      hammering
# 1           1      1      39        4    315    office      hammering
# 2           2      1      39        5    324    office         sawing
# 3           3      1      39        6    341    office  hole-punching
# 4           4      1      39        7    267   kitchen  hole-punching
#
#   Compatibility  PT ProbeType          Probe  CorrectResponse  Response  \
# 0    compatible  83     Scene       workshop               39        37
# 1  incompatible  50    Action      hammering               39        39
# 2  incompatible  50    Action       stamping               37        37
# 3    compatible  33     Scene       workshop               37        37
# 4  incompatible  50    Action  hole-punching               39        39
#
#        RT   transRT       zRT
# 0  1221.3  0.693395  0.959455
# 1  1014.3  0.867728  1.171207
# 2   921.3  0.799823  0.815164
# 3   688.0  0.591583  0.025715
# 4   690.1  0.598509 -0.240382

# %% [markdown]
# With wrong responses

# %%
results = sm.stats.AnovaRM(df_trials,
                           depvar='RT', subject='subID',
                           aggregate_func='mean',
                           within=['PT', 'Compatibility', 'ProbeType']).fit()
print(results)
# Out:
#                          Anova
# ========================================================
#                            F Value Num DF  Den DF Pr > F
# --------------------------------------------------------
# PT                          4.1582 5.0000 75.0000 0.0022
# Compatibility               5.2095 1.0000 15.0000 0.0375
# ProbeType                  26.5697 1.0000 15.0000 0.0001
# PT:Compatibility            1.9912 5.0000 75.0000 0.0896
# PT:ProbeType                4.8720 5.0000 75.0000 0.0007
# Compatibility:ProbeType    13.3538 1.0000 15.0000 0.0023
# PT:Compatibility:ProbeType  2.9906 5.0000 75.0000 0.0162
# ========================================================

# %% [markdown]
# Excluding wrong responses

# %%
results = sm.stats.AnovaRM(df_trials[df_trials.CorrectResponse == df_trials.Response],
                           depvar='RT', subject='subID',
                           aggregate_func='mean',
                           within=['PT', 'Compatibility', 'ProbeType']).fit()
print(results)
# Out:
#                          Anova
# ========================================================
#                            F Value Num DF  Den DF Pr > F
# --------------------------------------------------------
# PT                          4.1188 5.0000 95.0000 0.0020
# Compatibility              13.7171 1.0000 19.0000 0.0015
# ProbeType                  10.7075 1.0000 19.0000 0.0040
# PT:Compatibility            0.7130 5.0000 95.0000 0.6151
# PT:ProbeType                5.7421 5.0000 95.0000 0.0001
# Compatibility:ProbeType    18.9759 1.0000 19.0000 0.0003
# PT:Compatibility:ProbeType  2.7116 5.0000 95.0000 0.0246
# ========================================================

# %% [markdown]
# For actions separately

# %%
results_actions = sm.stats.AnovaRM(df_trials[
                                        (df_trials.CorrectResponse == df_trials.Response) & 
                                        (df_trials.ProbeType == 'Action')],
                                   aggregate_func='mean',
                                   depvar='RT', subject='subID', 
                                   within=['PT', 'Compatibility']).fit()
print(results_actions)
# Out:
#                     Anova
# ==============================================
#                  F Value Num DF  Den DF Pr > F
# ----------------------------------------------
# PT                7.8215 5.0000 95.0000 0.0000
# Compatibility     0.7749 1.0000 19.0000 0.3897
# PT:Compatibility  1.5005 5.0000 95.0000 0.1970
# ==============================================

# %% [markdown]
# Scenes

# %%
results_scenes = sm.stats.AnovaRM(df_trials[
                                        (df_trials.CorrectResponse == df_trials.Response) & 
                                        (df_trials.ProbeType == 'Scene')],
                                  aggregate_func='mean',
                                  depvar='RT', subject='subID', 
                                  within=['PT', 'Compatibility']).fit()
print(results_scenes)
# Out:
#                     Anova
# ==============================================
#                  F Value Num DF  Den DF Pr > F
# ----------------------------------------------
# PT                0.9140 5.0000 75.0000 0.4767
# Compatibility    15.9472 1.0000 15.0000 0.0012
# PT:Compatibility  2.1063 5.0000 75.0000 0.0739
# ==============================================

# %% [markdown]
# Only compatible & correct

# %%
results = sm.stats.AnovaRM(df_trials[
                                (df_trials.Compatibility == 'compatible') &
                                (df_trials.CorrectResponse == df_trials.Response)],
                           depvar='RT', subject='subID',
                           aggregate_func='mean',
                           within=['PT', 'ProbeType']).fit()
print(results)
# Out:
#                   Anova
# ==========================================
#              F Value Num DF  Den DF Pr > F
# ------------------------------------------
# PT            1.9851 5.0000 75.0000 0.0906
# ProbeType    19.1833 1.0000 15.0000 0.0005
# PT:ProbeType  2.3987 5.0000 75.0000 0.0450
# ==========================================
